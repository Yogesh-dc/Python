# %%
#imports
from datetime import datetime


# space
mtab1="\t"
mtab2="\t\t"
mtab3="\t\t\t"
mtab4="\t\t\t\t"
mtab5="\t\t\t\t\t"
mtab6="\t\t\t\t\t\t"
mtab7="\t\t\t\t\t\t\t"
# demographic details
name=input("Please enter a name: ")
cname=input("Please enter course name: ")
ccode=input("Please enter a course code: ")
enrollno=input("Please enter enrollment number: ")
regno=input("Please enter registration number: ")

# Get the current date
current_date = datetime.now().date()

# marks obtained in each subject
a=eval(input("Please enter marks in English: "))
b=eval(input("Please enter marks in Math: "))
c=eval(input("Please enter marks in Hindi: "))
d=eval(input("Please enter marks in Science: "))
e=eval(input("Please enter marks in SST: "))
f=eval(input("Please enter marks in Sanskrit: "))
# total marks        
marks=a+b+c+d+e+f
# percentage obtained
percent = (marks/600)*100
print("_________________________________________________________________________________________________________________")
print("\n",mtab5,"Waris International School")
print("\n",mtab4,"Rajasthan Board of Secondary Education, Ajmer, Jaipur")
print("_________________________________________________________________________________________________________________")

# print demographic info
print("NAME:",name,mtab1,"COURSE:", cname,mtab1,"COURSE CODE:", ccode,mtab1,"ENROLLMENT NO:", enrollno,mtab1,"REGISTRATION NO:", 
regno,mtab1,"\n","DATE" ,current_date)
print("_________________________________________________________________________________________________________________")
# print subect with marks obtained

print("\n\n","SUBJECT CODE",mtab1,"SUBJECT",mtab2,"TOTAL MARKS",mtab3,"TOTAL MARKS OBTAINED")
print("\n","120",mtab2,"ENGLISH",mtab2,"100",mtab5,a)
print("\n","120",mtab2,"MATH   ",mtab2,"100",mtab5,b)
print("\n","120",mtab2,"HINDI  ",mtab2,"100",mtab5,c)
print("\n","120",mtab2,"SCIENCE",mtab2,"100",mtab5,d)
print("\n","120",mtab2,"SST    ",mtab2,"100",mtab5,e)
print("\n","120",mtab2,"SANSKRIT",mtab2,"100",mtab5,f)
print("_________________________________________________________________________________________________________________")

#PRINT TOTAL MARKS AND PERCENTAGE OBTAINED

print(mtab5,"600",mtab5,marks)
print("_________________________________________________________________________________________________________________")

print("PERCENTAGE OBTAINED: ","%.2f" % percent)
# Out:
# Please enter a name: YOGESH CHOUDHARY
# Please enter course name: 12TH
# Please enter a course code: 120
# Please enter enrollment number: 25040
# Please enter registration number: RAJ/120
# Please enter marks in English: 96
# Please enter marks in Math: 98
# Please enter marks in Hindi: 91
# Please enter marks in Science: 85
# Please enter marks in SST: 89
# Please enter marks in Sanskrit: 88
# _________________________________________________________________________________________________________________
#
#  					 Waris International School
#
#  				 Rajasthan Board of Secondary Education, Ajmer, Jaipur
# _________________________________________________________________________________________________________________
# NAME: YOGESH CHOUDHARY 	 COURSE: 12TH 	 COURSE CODE: 120 	 ENROLLMENT NO: 25040 	 REGISTRATION NO: RAJ/120
#  DATE 2024-07-08
# _________________________________________________________________________________________________________________
#
#
# ...
